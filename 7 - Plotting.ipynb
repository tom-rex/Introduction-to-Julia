# %% [markdown]
# # Plotting
#
# ## Basics
# There are a few different ways to plot in Julia (including calling PyPlot). <br>
#
# Here we'll show you how to use `Plots.jl`.  If it's not installed yet, you need to use the package manager to install it, and Julia will precompile it for you the first time you use it:

# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#    Resolving package versions...
#    Installed JpegTurbo_jll ──────────────── v3.1.1+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed libfdk_aac_jll ─────────────── v2.0.3+0
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed GR_jll ─────────────────────── v0.73.16+0
#    Installed Libmount_jll ───────────────── v2.41.0+0
#    Installed LoggingExtras ──────────────── v1.1.0
#    Installed Opus_jll ───────────────────── v1.3.3+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Measures ───────────────────── v0.3.2
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed Unitful ────────────────────── v1.23.1
#    Installed Contour ────────────────────── v0.6.3
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed OpenSSL ────────────────────── v1.5.0
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed HTTP ───────────────────────── v1.10.16
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────── v2.16.0+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed FFMPEG ─────────────────────── v0.4.2
#    Installed Missings ───────────────────── v1.2.0
#    Installed IrrationalConstants ────────── v0.2.4
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Pango_jll ──────────────────── v1.56.3+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed xkbcommon_jll ──────────────── v1.8.1+0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed NaNMath ────────────────────── v1.1.3
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed ColorSchemes ───────────────── v3.29.0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed TranscodingStreams ─────────── v0.11.3
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed GR ─────────────────────────── v0.73.16
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed StatsAPI ───────────────────── v1.7.1
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed Compat ─────────────────────── v4.16.0
#    Installed DataStructures ─────────────── v0.18.22
#    Installed StatsBase ──────────────────── v0.34.5
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed libpng_jll ─────────────────── v1.6.48+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed libaom_jll ─────────────────── v3.11.0+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Scratch ────────────────────── v1.2.1
#    Installed Plots ──────────────────────── v1.40.13
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.4+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Libtiff_jll ────────────────── v4.7.1+0
#    Installed Expat_jll ──────────────────── v2.6.5+0
#    Installed Format ─────────────────────── v1.3.7
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed OrderedCollections ─────────── v1.8.1
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Ogg_jll ────────────────────── v1.3.5+1
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed LogExpFunctions ────────────── v0.3.29
#    Installed AliasTables ────────────────── v1.1.3
#    Installed MacroTools ─────────────────── v0.5.16
#    Installed Libuuid_jll ────────────────── v2.41.0+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed DocStringExtensions ────────── v0.9.5
#    Installed Wayland_protocols_jll ──────── v1.44.0+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed libass_jll ─────────────────── v0.15.2+0
#    Installed XML2_jll ───────────────────── v2.13.6+1
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Gettext_jll ────────────────── v0.21.0+0
#    Installed Wayland_jll ────────────────── v1.23.1+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed Latexify ───────────────────── v0.16.8
#    Installed OpenSSL_jll ────────────────── v3.5.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed FFMPEG_jll ─────────────────── v4.4.4+1
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed Xorg_libXfixes_jll ─────────── v6.0.1+0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed LAME_jll ───────────────────── v3.100.2+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+0
#    Installed Glib_jll ───────────────────── v2.84.0+0
#    Installed Qt6Base_jll ────────────────── v6.8.2+1
#    Installed libvorbis_jll ──────────────── v1.3.7+2
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed Requires ───────────────────── v1.3.1
#    Installed URIs ───────────────────────── v1.5.2
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed SortingAlgorithms ──────────── v1.2.1
#    Installed UnitfulLatexify ────────────── v1.7.0
#     Updating `C:\Users\Tom Cummings\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.40.13
#     Updating `C:\Users\Tom Cummings\.julia\environments\v1.11\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.29.0
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [34da2185] + Compat v4.16.0
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.22
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.16
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.16
#   [92d709cd] + IrrationalConstants v0.2.4
#   [1019f520] + JLFzf v0.1.11
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.8
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.1.0
#   [1914dd2f] + MacroTools v0.5.16
#   [442fdcdd] + Measures v0.3.2
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.1.3
#   [4d8831e6] + OpenSSL v1.5.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.13
#   [43287f4e] + PtrArrays v1.3.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [860ef19b] + StableRNGs v1.0.3
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.5
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [5c2747f8] + URIs v1.5.2
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.23.1
#   [45397f5d] + UnitfulLatexify v1.7.0
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.16.0+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.16+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.84.0+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.0+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.41.0+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v3.5.0+0
#   [91d4177d] + Opus_jll v1.3.3+0
#   [36c8627f] + Pango_jll v1.56.3+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+1
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+0
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.23.1+0
#   [2381bf8a] + Wayland_protocols_jll v1.44.0+0
# ⌅ [02c8fc9c] + XML2_jll v2.13.6+1
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.1+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.11.0+0
#   [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.3+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.48+0
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.7+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.8.1+0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [8dfed614] + Test v1.11.0
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    1196.5 ms  ✓ LaTeXStrings
#     896.9 ms  ✓ Contour
#     957.8 ms  ✓ TensorCore
#     952.1 ms  ✓ StatsAPI
#     934.7 ms  ✓ Measures
#    1354.6 ms  ✓ OrderedCollections
#    2412.0 ms  ✓ Format
#    2044.6 ms  ✓ Grisu
#    1515.7 ms  ✓ Requires
#    1325.5 ms  ✓ StableRNGs
#    1626.6 ms  ✓ Unzip
#    1507.8 ms  ✓ DocStringExtensions
#    1055.7 ms  ✓ SimpleBufferStream
#    1765.8 ms  ✓ URIs
#    1047.5 ms  ✓ PtrArrays
#    3318.3 ms  ✓ IrrationalConstants
#    1753.0 ms  ✓ TranscodingStreams
#    5985.9 ms  ✓ MacroTools
#    1903.7 ms  ✓ NaNMath
#    1771.6 ms  ✓ DelimitedFiles
#    1067.7 ms  ✓ DataAPI
#    1004.4 ms  ✓ BitFlags
#    1314.3 ms  ✓ Scratch
#    2182.5 ms  ✓ Statistics → SparseArraysExt
#    2096.9 ms  ✓ ConcurrentUtilities
#    1605.3 ms  ✓ LoggingExtras
#    1537.8 ms  ✓ Compat
#    2000.0 ms  ✓ ExceptionUnwrapping
#    1780.8 ms  ✓ OpenSSL_jll
#    1675.6 ms  ✓ Graphite2_jll
#    1531.8 ms  ✓ Libmount_jll
#    1506.9 ms  ✓ EpollShim_jll
#    4646.5 ms  ✓ UnicodeFun
#    1681.4 ms  ✓ LLVMOpenMP_jll
#    1519.6 ms  ✓ Xorg_libICE_jll
#    1736.4 ms  ✓ Bzip2_jll
#    1503.9 ms  ✓ Xorg_libXau_jll
#    1744.3 ms  ✓ libpng_jll
#    1654.2 ms  ✓ libfdk_aac_jll
#    1698.6 ms  ✓ LAME_jll
#    1579.8 ms  ✓ LERC_jll
#    1611.4 ms  ✓ fzf_jll
#    1772.6 ms  ✓ JpegTurbo_jll
#    1827.3 ms  ✓ XZ_jll
#    1605.5 ms  ✓ Ogg_jll
#    1471.0 ms  ✓ mtdev_jll
#    1490.4 ms  ✓ Xorg_libXdmcp_jll
#    1681.7 ms  ✓ x265_jll
#    1662.8 ms  ✓ x264_jll
#    1692.5 ms  ✓ Zstd_jll
#    1714.8 ms  ✓ libaom_jll
#    1669.2 ms  ✓ Expat_jll
#    1608.7 ms  ✓ LZO_jll
#    1635.2 ms  ✓ Opus_jll
#    1337.1 ms  ✓ Xorg_xtrans_jll
#    1312.8 ms  ✓ libevdev_jll
#    1540.1 ms  ✓ Libiconv_jll
#    1475.4 ms  ✓ Libffi_jll
#    1336.1 ms  ✓ eudev_jll
#    1374.5 ms  ✓ Wayland_protocols_jll
#    1289.8 ms  ✓ Libuuid_jll
#    1508.4 ms  ✓ FriBidi_jll
#    1067.9 ms  ✓ Showoff
#    1215.6 ms  ✓ AliasTables
#    1640.6 ms  ✓ LogExpFunctions
#    1463.7 ms  ✓ CodecZlib
#    4153.6 ms  ✓ RecipesBase
#    1576.7 ms  ✓ Missings
#    1474.5 ms  ✓ RelocatableFolders
#    5094.4 ms  ✓ ColorVectorSpace
#    1147.9 ms  ✓ Compat → CompatLinearAlgebraExt
#    1523.5 ms  ✓ Pixman_jll
#    1309.5 ms  ✓ Xorg_libSM_jll
#    1577.4 ms  ✓ FreeType2_jll
#    3991.0 ms  ✓ OpenSSL
#    7636.5 ms  ✓ Latexify
#    2042.8 ms  ✓ libvorbis_jll
#    3178.5 ms  ✓ JLFzf
#    1749.9 ms  ✓ Xorg_libxcb_jll
#    1534.7 ms  ✓ Dbus_jll
#    2226.6 ms  ✓ Libtiff_jll
#    1540.0 ms  ✓ libinput_jll
#    2100.5 ms  ✓ XML2_jll
#    2264.3 ms  ✓ Fontconfig_jll
#    4046.9 ms  ✓ DataStructures
#    1753.9 ms  ✓ Latexify → SparseArraysExt
#    1332.9 ms  ✓ Xorg_xcb_util_jll
#    1382.0 ms  ✓ Xorg_libX11_jll
#    1417.7 ms  ✓ Wayland_jll
#    1866.6 ms  ✓ Gettext_jll
#    8485.6 ms  ✓ ColorSchemes
#    1677.3 ms  ✓ SortingAlgorithms
#    1526.2 ms  ✓ Xorg_xcb_util_image_jll
#    1589.8 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1788.3 ms  ✓ Xorg_xcb_util_renderutil_jll
#    1803.8 ms  ✓ Xorg_xcb_util_wm_jll
#    1686.6 ms  ✓ Xorg_libXrender_jll
#    1541.7 ms  ✓ Xorg_libXext_jll
#    1536.5 ms  ✓ Xorg_libXfixes_jll
#    1480.5 ms  ✓ Xorg_libxkbfile_jll
#    2246.8 ms  ✓ Glib_jll
#    1540.3 ms  ✓ Xorg_xcb_util_cursor_jll
#    1636.4 ms  ✓ Xorg_libXinerama_jll
#    5804.7 ms  ✓ StatsBase
#    1663.1 ms  ✓ Xorg_libXrandr_jll
#    1533.1 ms  ✓ Libglvnd_jll
#    1567.9 ms  ✓ Xorg_libXcursor_jll
#    1580.6 ms  ✓ Xorg_libXi_jll
#    1583.9 ms  ✓ Xorg_xkbcomp_jll
#    1679.8 ms  ✓ Xorg_xkeyboard_config_jll
#   54092.5 ms  ✓ Unitful
#    2950.2 ms  ✓ Cairo_jll
#    1532.3 ms  ✓ xkbcommon_jll
#    2147.1 ms  ✓ HarfBuzz_jll
#    2247.7 ms  ✓ Unitful → PrintfExt
#    1519.9 ms  ✓ Vulkan_Loader_jll
#    2054.5 ms  ✓ libass_jll
#    2122.2 ms  ✓ Pango_jll
#    3631.1 ms  ✓ UnitfulLatexify
#    1540.2 ms  ✓ libdecor_jll
#    3620.4 ms  ✓ Qt6Base_jll
#    3820.6 ms  ✓ FFMPEG_jll
#    1682.9 ms  ✓ GLFW_jll
#    2214.5 ms  ✓ FFMPEG
#    5253.9 ms  ✓ Qt6ShaderTools_jll
#    4363.0 ms  ✓ GR_jll
#   30429.3 ms  ✓ PlotUtils
#    6971.6 ms  ✓ Qt6Declarative_jll
#    1539.1 ms  ✓ Qt6Wayland_jll
#   48011.6 ms  ✓ HTTP
#    6715.8 ms  ✓ PlotThemes
#    9815.5 ms  ✓ RecipesPipeline
#    7819.6 ms  ✓ GR
#  129655.9 ms  ✓ Plots
#    5930.7 ms  ✓ Plots → UnitfulExt
#    6392.7 ms  ✓ Plots → IJuliaExt
#   136 dependencies successfully precompiled in 232 seconds. 57 already precompiled.

# %% [markdown]
# One of the advantages to `Plots.jl` is that it allows you to seamlessly change backends. In this notebook, we'll try out the `gr()` and `plotlyjs()` backends.<br>
#
# In the name of scientific inquiry, let's use this notebook to examine the relationship between the global temperature and the number of pirates between roughly 1860 and 2000.

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17];

# %% [markdown]
# Plots supports multiple backends — that is, libraries that actually do the drawing — all with the same API. To start out, let's try the GR backend.  You choose it with a call to `gr()`:

# %%
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# and now we can use commands like `plot` and `scatter` to generate plots.

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points")

# %% [markdown]
# The `!` at the end of the `scatter!` function name makes `scatter!` a mutating function, indicating that the scattered points will be added onto the pre-existing plot.
#
# In contrast, see what happens when you replace `scatter!` in the above with the non-mutating function `scatter`.
#
# Next, let's update this plot with the `xlabel!`, `ylabel!`, and `title!` commands to add more information to our plot.

# %%
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %% [markdown]
# This still doesn't look quite right. The number of pirates has decreased since 1860, so reading the plot from left to right is like looking backwards in time rather than forwards. Let's flip the x axis to better see how pirate populations have caused global temperatures to change over time!

# %%
xflip!()

# %% [markdown]
# And there we have it!
#
# Note: We've had some confusion about this exercise. :) This is a joke about how people often conflate correlation and causation.
#
# **Without changing syntax, we can create this plot with the UnicodePlots backend**

# %%
Pkg.add("UnicodePlots")
unicodeplots()
# Out:
#    Resolving package versions...
#    Installed MarchingCubes ──── v0.1.11
#    Installed StaticArraysCore ─ v1.4.3
#    Installed Crayons ────────── v4.1.1
#    Installed StaticArrays ───── v1.9.13
#    Installed UnicodePlots ───── v3.7.2
#     Updating `C:\Users\Tom Cummings\.julia\environments\v1.11\Project.toml`
#   [b8865327] + UnicodePlots v3.7.2
#     Updating `C:\Users\Tom Cummings\.julia\environments\v1.11\Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [299715c1] + MarchingCubes v0.1.11
#   [90137ffa] + StaticArrays v1.9.13
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [b8865327] + UnicodePlots v3.7.2
# Precompiling project...
#     821.7 ms  ✓ StaticArraysCore
#    1952.0 ms  ✓ Crayons
#   10996.4 ms  ✓ StaticArrays
#    1288.8 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    5664.9 ms  ✓ MarchingCubes
#   70383.2 ms  ✓ UnicodePlots
#    3187.7 ms  ✓ UnicodePlots → UnitfulExt
#   7 dependencies successfully precompiled in 92 seconds. 193 already precompiled.
# Plots.UnicodePlotsBackend()

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points") 
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")
# Out:
#                           Influence of pirate population on global warming
#                           ┌────────────────────────────────────────┐
#                    15.842 │⠀⚬⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ line
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ points
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠈⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#    Global Temperature (C) │⠀⡇⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⚬⠤⠤⠤⢄⣀⣀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                    14.358 │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠒⠒⠒⠒⠒⠤⚬⠀│
#                           └────────────────────────────────────────┘
#                           ⠀-1332.49Number of Pirates [Approximate]46349.5⠀

# %% [markdown]
# And notice how this second plot differs from the first!  Using text like this is a little silly in a Jupyter notebook where we have fancy drawing capabilities, but it can be very useful for quick and dirty visualization in a terminal.

# %% [markdown]
# ### Exercises
#
# #### 8.1
# Given
# ```julia
# x = -10:10
# ```
# plot y vs. x for $y = x^2$.  You may want to change backends back again.

# %%
gr()

x = -10:10
y = x.^2

plot(x, y, label = "line")
scatter!(x,y, label = "points")

# %% [markdown]
# #### 8.2
# Execute the following code

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %% [markdown]
# and then create a $4x1$ plot that uses `p1`, `p2`, `p3`, and `p4` as subplots.

# %%
plot(p1, p2, p3, p4, layout = (4, 1), legend = false)
